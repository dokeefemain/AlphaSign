# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import pickle
import cv2
import os
import pandas as pd
from PIL import Image
import imutils

# %%
Adata = pd.read_csv("lib/datasets/LISA/allAnnotations.csv", delimiter=';')
Adata
# Out:
#                                                Filename   Annotation tag  \
# 0     aiua120214-0/frameAnnotations-DataLog02142012_...             stop
# 1     aiua120214-0/frameAnnotations-DataLog02142012_...  speedLimitUrdbl
# 2     aiua120214-0/frameAnnotations-DataLog02142012_...             stop
# 3     aiua120214-0/frameAnnotations-DataLog02142012_...     speedLimit25
# 4     aiua120214-0/frameAnnotations-DataLog02142012_...     speedLimit25
# ...                                                 ...              ...
# 7850  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7851  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7852  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7853  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7854  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
#
#       Upper left corner X  Upper left corner Y  Lower right corner X  \
# 0                     862                  104                   916
# 1                     425                  197                   438
# 2                     922                   88                   982
# 3                     447                  193                   461
# 4                     469                  189                   483
# ...                   ...                  ...                   ...
# 7850                   41                  209                    65
# 7851                  526                  213                   543
# 7852                  546                  208                   564
# 7853                  573                  204                   592
# 7854                  604                  196                   628
#
#       Lower right corner Y Occluded,On another road  \
# 0                      158                      0,0
# 1                      213                      0,0
# 2                      148                      1,0
# 3                      210                      0,0
# 4                      207                      0,0
# ...                    ...                      ...
# 7850                   239                      0,0
# 7851                   233                      0,0
# 7852                   230                      0,0
# 7853                   228                      0,0
# 7854                   223                      0,0
#
#                                            Origin file  Origin frame number  \
# 0     aiua120214-0/DataLog02142012_external_camera.avi                 2667
# 1     aiua120214-0/DataLog02142012_external_camera.avi                 2667
# 2     aiua120214-0/DataLog02142012_external_camera.avi                 2672
# 3     aiua120214-0/DataLog02142012_external_camera.avi                 2672
# 4     aiua120214-0/DataLog02142012_external_camera.avi                 2677
# ...                                                ...                  ...
# 7850                                 vid9/MVI_0121.MOV                 8813
# 7851                                 vid9/MVI_0121.MOV                 8875
# 7852                                 vid9/MVI_0121.MOV                 8880
# 7853                                 vid9/MVI_0121.MOV                 8885
# 7854                                 vid9/MVI_0121.MOV                 8890
#
#                    Origin track  Origin track frame number
# 0           stop_1330545910.avi                          2
# 1           stop_1330545910.avi                          2
# 2           stop_1330545910.avi                          7
# 3           stop_1330545910.avi                          7
# 4           stop_1330545910.avi                         12
# ...                         ...                        ...
# 7850  speedLimit_1324866802.avi                         22
# 7851  speedLimit_1324866807.avi                          2
# 7852  speedLimit_1324866807.avi                          7
# 7853  speedLimit_1324866807.avi                         12
# 7854  speedLimit_1324866807.avi                         17
#
# [7855 rows x 11 columns]

# %%
#max image size
height = 100
width = 100
data = []
labels = []
bboxes =[]
imagePaths=[]
path = "lib/datasets/LISA/"
test = 0
for i in range(len(Adata["Filename"])):
    file = Adata["Filename"][i]
    sign = Adata["Annotation tag"][i]
    image = Image.open(path+file)
    h, w = image.height,image.width
    image = image.resize((width,height))
    image = np.asarray(image)
    data.append(image)
    labels.append(sign)
    bboxes.append((float(Adata['Upper left corner X'][i])/w,float(Adata['Upper left corner Y'][i])/h,float(Adata['Lower right corner X'][i])/w,float(Adata['Lower right corner Y'][i])/h))

# %%
h,w
# Out:
# (480, 640)

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
bboxes = np.array(bboxes, dtype="float32")
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
split = train_test_split(data, labels, bboxes,test_size=0.20, random_state=42)
(trainImages, testImages) = split[:2]
(trainLabels, testLabels) = split[2:4]
(trainBBoxes, testBBoxes) = split[4:6]

# %%
vgg = VGG16(weights="imagenet", include_top=False,input_tensor=Input(shape=(100, 100, 3)))
vgg.trainable = False
flatten = vgg.output
flatten = Flatten()(flatten)

# %%
bboxHead = Dense(128, activation="relu")(flatten)
bboxHead = Dense(64, activation="relu")(bboxHead)
bboxHead = Dense(32, activation="relu")(bboxHead)
bboxHead = Dense(4, activation="sigmoid",name="bounding_box")(bboxHead)
softmaxHead = Dense(512, activation="relu")(flatten)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(512, activation="relu")(softmaxHead)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(len(lb.classes_), activation="softmax",name="class_label")(softmaxHead)
# put together our model which accept an input image and then output
# bounding box coordinates and a class label
model = Model(inputs=vgg.input,outputs=(bboxHead, softmaxHead))

# %%
losses = {"class_label": "categorical_crossentropy","bounding_box": "mean_squared_error",}
lossWeights = {"class_label": 1.0,"bounding_box": 1.0
}
opt = 'Adam'
model.compile(loss=losses, optimizer=opt, metrics=["accuracy"], loss_weights=lossWeights)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 100, 100, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 100, 100, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 50, 50, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 50, 50, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 50, 50, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 25, 25, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 25, 25, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 25, 25, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 25, 25, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 12, 12, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 12, 12, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 12, 12, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 12, 12, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 6, 6, 512)    0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 6, 6, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 6, 6, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 6, 6, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 3, 3, 512)    0           ['block5_conv3[0][0]']
#
#  flatten (Flatten)              (None, 4608)         0           ['block5_pool[0][0]']
#
#  dense_3 (Dense)                (None, 512)          2359808     ['flatten[0][0]']
#
#  dense (Dense)                  (None, 128)          589952      ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense_3[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_4 (Dense)                (None, 512)          262656      ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_4[0][0]']
#
#  bounding_box (Dense)           (None, 4)            132         ['dense_2[0][0]']
#
#  class_label (Dense)            (None, 47)           24111       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 17,961,683
# Trainable params: 3,246,995
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________
# None

# %%
trainTargets = {"class_label": trainLabels,"bounding_box": trainBBoxes
}
testTargets = {"class_label": testLabels,"bounding_box": testBBoxes
}

# %%
H = model.fit(trainImages, trainTargets,validation_data=(testImages, testTargets),batch_size=32,epochs=30,verbose=1)
# Out:
# Epoch 1/30
# 197/197 [==============================] - 84s 422ms/step - loss: 2.7487 - bounding_box_loss: 0.0240 - class_label_loss: 2.7248 - bounding_box_accuracy: 0.6370 - class_label_accuracy: 0.2755 - val_loss: 2.2229 - val_bounding_box_loss: 0.0217 - val_class_label_loss: 2.2011 - val_bounding_box_accuracy: 0.7594 - val_class_label_accuracy: 0.3826
# Epoch 2/30
# 197/197 [==============================] - 82s 417ms/step - loss: 2.2375 - bounding_box_loss: 0.0186 - class_label_loss: 2.2190 - bounding_box_accuracy: 0.7298 - class_label_accuracy: 0.3806 - val_loss: 1.7940 - val_bounding_box_loss: 0.0217 - val_class_label_loss: 1.7722 - val_bounding_box_accuracy: 0.4341 - val_class_label_accuracy: 0.5029
# Epoch 3/30
# 197/197 [==============================] - 82s 416ms/step - loss: 1.9144 - bounding_box_loss: 0.0159 - class_label_loss: 1.8985 - bounding_box_accuracy: 0.8141 - class_label_accuracy: 0.4561 - val_loss: 1.5501 - val_bounding_box_loss: 0.0167 - val_class_label_loss: 1.5334 - val_bounding_box_accuracy: 0.8370 - val_class_label_accuracy: 0.5729
# Epoch 4/30
# 197/197 [==============================] - 82s 415ms/step - loss: 1.6906 - bounding_box_loss: 0.0140 - class_label_loss: 1.6766 - bounding_box_accuracy: 0.8299 - class_label_accuracy: 0.5076 - val_loss: 1.2857 - val_bounding_box_loss: 0.0180 - val_class_label_loss: 1.2676 - val_bounding_box_accuracy: 0.7346 - val_class_label_accuracy: 0.6537
# Epoch 5/30
# 197/197 [==============================] - 83s 421ms/step - loss: 1.5226 - bounding_box_loss: 0.0132 - class_label_loss: 1.5094 - bounding_box_accuracy: 0.8267 - class_label_accuracy: 0.5492 - val_loss: 1.0844 - val_bounding_box_loss: 0.0157 - val_class_label_loss: 1.0687 - val_bounding_box_accuracy: 0.8205 - val_class_label_accuracy: 0.7244
# Epoch 6/30
# 197/197 [==============================] - 87s 443ms/step - loss: 1.4021 - bounding_box_loss: 0.0126 - class_label_loss: 1.3895 - bounding_box_accuracy: 0.8369 - class_label_accuracy: 0.5775 - val_loss: 0.9788 - val_bounding_box_loss: 0.0182 - val_class_label_loss: 0.9606 - val_bounding_box_accuracy: 0.7282 - val_class_label_accuracy: 0.7199
# Epoch 7/30
# 197/197 [==============================] - 85s 434ms/step - loss: 1.2716 - bounding_box_loss: 0.0122 - class_label_loss: 1.2595 - bounding_box_accuracy: 0.8436 - class_label_accuracy: 0.6187 - val_loss: 0.8614 - val_bounding_box_loss: 0.0166 - val_class_label_loss: 0.8448 - val_bounding_box_accuracy: 0.8447 - val_class_label_accuracy: 0.7556
# Epoch 8/30
# 197/197 [==============================] - 84s 427ms/step - loss: 1.2373 - bounding_box_loss: 0.0111 - class_label_loss: 1.2262 - bounding_box_accuracy: 0.8574 - class_label_accuracy: 0.6230 - val_loss: 0.7964 - val_bounding_box_loss: 0.0173 - val_class_label_loss: 0.7790 - val_bounding_box_accuracy: 0.7944 - val_class_label_accuracy: 0.7607
# Epoch 9/30
# 197/197 [==============================] - 84s 428ms/step - loss: 1.1385 - bounding_box_loss: 0.0111 - class_label_loss: 1.1275 - bounding_box_accuracy: 0.8550 - class_label_accuracy: 0.6445 - val_loss: 0.8397 - val_bounding_box_loss: 0.0155 - val_class_label_loss: 0.8241 - val_bounding_box_accuracy: 0.8173 - val_class_label_accuracy: 0.7696
# Epoch 10/30
# 197/197 [==============================] - 84s 429ms/step - loss: 1.1383 - bounding_box_loss: 0.0106 - class_label_loss: 1.1277 - bounding_box_accuracy: 0.8574 - class_label_accuracy: 0.6466 - val_loss: 0.7260 - val_bounding_box_loss: 0.0148 - val_class_label_loss: 0.7112 - val_bounding_box_accuracy: 0.8294 - val_class_label_accuracy: 0.7785
# Epoch 11/30
# 197/197 [==============================] - 89s 453ms/step - loss: 1.0786 - bounding_box_loss: 0.0102 - class_label_loss: 1.0684 - bounding_box_accuracy: 0.8662 - class_label_accuracy: 0.6668 - val_loss: 0.6854 - val_bounding_box_loss: 0.0156 - val_class_label_loss: 0.6698 - val_bounding_box_accuracy: 0.8370 - val_class_label_accuracy: 0.7868
# Epoch 12/30
# 197/197 [==============================] - 91s 461ms/step - loss: 1.0225 - bounding_box_loss: 0.0098 - class_label_loss: 1.0127 - bounding_box_accuracy: 0.8665 - class_label_accuracy: 0.6768 - val_loss: 0.6964 - val_bounding_box_loss: 0.0148 - val_class_label_loss: 0.6816 - val_bounding_box_accuracy: 0.8275 - val_class_label_accuracy: 0.7708
# Epoch 13/30
# 197/197 [==============================] - 91s 460ms/step - loss: 1.0112 - bounding_box_loss: 0.0099 - class_label_loss: 1.0013 - bounding_box_accuracy: 0.8679 - class_label_accuracy: 0.6798 - val_loss: 0.6789 - val_bounding_box_loss: 0.0144 - val_class_label_loss: 0.6646 - val_bounding_box_accuracy: 0.8129 - val_class_label_accuracy: 0.7791
# Epoch 14/30
# 197/197 [==============================] - 91s 460ms/step - loss: 0.9680 - bounding_box_loss: 0.0093 - class_label_loss: 0.9587 - bounding_box_accuracy: 0.8791 - class_label_accuracy: 0.6927 - val_loss: 0.6297 - val_bounding_box_loss: 0.0150 - val_class_label_loss: 0.6147 - val_bounding_box_accuracy: 0.8014 - val_class_label_accuracy: 0.8027
# Epoch 15/30
# 197/197 [==============================] - 90s 458ms/step - loss: 0.9201 - bounding_box_loss: 0.0093 - class_label_loss: 0.9108 - bounding_box_accuracy: 0.8692 - class_label_accuracy: 0.7037 - val_loss: 0.5424 - val_bounding_box_loss: 0.0145 - val_class_label_loss: 0.5278 - val_bounding_box_accuracy: 0.8549 - val_class_label_accuracy: 0.8230
# Epoch 16/30
# 197/197 [==============================] - 90s 459ms/step - loss: 0.9107 - bounding_box_loss: 0.0096 - class_label_loss: 0.9011 - bounding_box_accuracy: 0.8652 - class_label_accuracy: 0.7074 - val_loss: 0.6031 - val_bounding_box_loss: 0.0153 - val_class_label_loss: 0.5877 - val_bounding_box_accuracy: 0.8453 - val_class_label_accuracy: 0.8326
# Epoch 17/30
# 197/197 [==============================] - 90s 459ms/step - loss: 0.8864 - bounding_box_loss: 0.0089 - class_label_loss: 0.8775 - bounding_box_accuracy: 0.8754 - class_label_accuracy: 0.7148 - val_loss: 0.5864 - val_bounding_box_loss: 0.0151 - val_class_label_loss: 0.5713 - val_bounding_box_accuracy: 0.7944 - val_class_label_accuracy: 0.8065
# Epoch 18/30
# 197/197 [==============================] - 91s 460ms/step - loss: 0.8481 - bounding_box_loss: 0.0089 - class_label_loss: 0.8392 - bounding_box_accuracy: 0.8730 - class_label_accuracy: 0.7222 - val_loss: 0.5458 - val_bounding_box_loss: 0.0136 - val_class_label_loss: 0.5322 - val_bounding_box_accuracy: 0.8466 - val_class_label_accuracy: 0.8281
# Epoch 19/30
# 197/197 [==============================] - 90s 459ms/step - loss: 0.8426 - bounding_box_loss: 0.0086 - class_label_loss: 0.8340 - bounding_box_accuracy: 0.8759 - class_label_accuracy: 0.7228 - val_loss: 0.5469 - val_bounding_box_loss: 0.0143 - val_class_label_loss: 0.5326 - val_bounding_box_accuracy: 0.8421 - val_class_label_accuracy: 0.8160
# Epoch 20/30
# 197/197 [==============================] - 91s 461ms/step - loss: 0.8146 - bounding_box_loss: 0.0086 - class_label_loss: 0.8060 - bounding_box_accuracy: 0.8830 - class_label_accuracy: 0.7304 - val_loss: 0.4943 - val_bounding_box_loss: 0.0144 - val_class_label_loss: 0.4799 - val_bounding_box_accuracy: 0.8300 - val_class_label_accuracy: 0.8294
# Epoch 21/30
# 197/197 [==============================] - 91s 461ms/step - loss: 0.7883 - bounding_box_loss: 0.0085 - class_label_loss: 0.7798 - bounding_box_accuracy: 0.8821 - class_label_accuracy: 0.7424 - val_loss: 0.5283 - val_bounding_box_loss: 0.0151 - val_class_label_loss: 0.5132 - val_bounding_box_accuracy: 0.8523 - val_class_label_accuracy: 0.8307
# Epoch 22/30
# 197/197 [==============================] - 92s 466ms/step - loss: 0.8427 - bounding_box_loss: 0.0083 - class_label_loss: 0.8344 - bounding_box_accuracy: 0.8843 - class_label_accuracy: 0.7199 - val_loss: 0.5158 - val_bounding_box_loss: 0.0144 - val_class_label_loss: 0.5014 - val_bounding_box_accuracy: 0.8466 - val_class_label_accuracy: 0.8313
# Epoch 23/30
# 197/197 [==============================] - 92s 469ms/step - loss: 0.8011 - bounding_box_loss: 0.0081 - class_label_loss: 0.7930 - bounding_box_accuracy: 0.8867 - class_label_accuracy: 0.7331 - val_loss: 0.4849 - val_bounding_box_loss: 0.0143 - val_class_label_loss: 0.4706 - val_bounding_box_accuracy: 0.8644 - val_class_label_accuracy: 0.8447
# Epoch 24/30
# 197/197 [==============================] - 92s 469ms/step - loss: 0.7809 - bounding_box_loss: 0.0081 - class_label_loss: 0.7728 - bounding_box_accuracy: 0.8867 - class_label_accuracy: 0.7430 - val_loss: 0.5151 - val_bounding_box_loss: 0.0157 - val_class_label_loss: 0.4993 - val_bounding_box_accuracy: 0.8491 - val_class_label_accuracy: 0.8390
# Epoch 25/30
# 197/197 [==============================] - 93s 473ms/step - loss: 0.7653 - bounding_box_loss: 0.0086 - class_label_loss: 0.7567 - bounding_box_accuracy: 0.8814 - class_label_accuracy: 0.7400 - val_loss: 0.4576 - val_bounding_box_loss: 0.0156 - val_class_label_loss: 0.4420 - val_bounding_box_accuracy: 0.8600 - val_class_label_accuracy: 0.8523
# Epoch 26/30
# 197/197 [==============================] - 93s 472ms/step - loss: 0.7495 - bounding_box_loss: 0.0078 - class_label_loss: 0.7418 - bounding_box_accuracy: 0.8918 - class_label_accuracy: 0.7457 - val_loss: 0.4825 - val_bounding_box_loss: 0.0140 - val_class_label_loss: 0.4685 - val_bounding_box_accuracy: 0.8561 - val_class_label_accuracy: 0.8440
# Epoch 27/30
# 197/197 [==============================] - 99s 502ms/step - loss: 0.7429 - bounding_box_loss: 0.0077 - class_label_loss: 0.7352 - bounding_box_accuracy: 0.8878 - class_label_accuracy: 0.7494 - val_loss: 0.4837 - val_bounding_box_loss: 0.0147 - val_class_label_loss: 0.4691 - val_bounding_box_accuracy: 0.8472 - val_class_label_accuracy: 0.8434
# Epoch 28/30
# 197/197 [==============================] - 93s 471ms/step - loss: 0.7596 - bounding_box_loss: 0.0078 - class_label_loss: 0.7518 - bounding_box_accuracy: 0.8861 - class_label_accuracy: 0.7500 - val_loss: 0.4538 - val_bounding_box_loss: 0.0151 - val_class_label_loss: 0.4387 - val_bounding_box_accuracy: 0.8498 - val_class_label_accuracy: 0.8479
# Epoch 29/30
# 197/197 [==============================] - 92s 468ms/step - loss: 0.7565 - bounding_box_loss: 0.0077 - class_label_loss: 0.7488 - bounding_box_accuracy: 0.8908 - class_label_accuracy: 0.7522 - val_loss: 0.4523 - val_bounding_box_loss: 0.0154 - val_class_label_loss: 0.4369 - val_bounding_box_accuracy: 0.8555 - val_class_label_accuracy: 0.8383
# Epoch 30/30
# 197/197 [==============================] - 93s 472ms/step - loss: 0.7159 - bounding_box_loss: 0.0076 - class_label_loss: 0.7083 - bounding_box_accuracy: 0.8913 - class_label_accuracy: 0.7570 - val_loss: 0.4987 - val_bounding_box_loss: 0.0151 - val_class_label_loss: 0.4836 - val_bounding_box_accuracy: 0.8593 - val_class_label_accuracy: 0.8313

# %%
lossNames = ["loss", "class_label_loss", "bounding_box_loss"]
N = np.arange(0,30)
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))
# loop over the loss names
for (i, l) in enumerate(lossNames):
	# plot the loss for both the training and validation data
	title = "Loss for {}".format(l) if l != "loss" else "Total loss"
	ax[i].set_title(title)
	ax[i].set_xlabel("Epoch #")
	ax[i].set_ylabel("Loss")
	ax[i].plot(N, H.history[l], label=l)
	ax[i].plot(N, H.history["val_" + l], label="val_" + l)
	ax[i].legend()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["bounding_box_accuracy"],
	label="bounding_box_accuracy")
plt.plot(N, H.history["val_bounding_box_accuracy"],
	label="val_bounding_box_accuracy_train")
plt.title("Bounding Box Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["class_label_accuracy"],
	label="class_label_train_acc")
plt.plot(N, H.history["val_class_label_accuracy"],
	label="val_class_label_acc")
plt.title("Class Label Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %%
model=load_model('testing_image.h5')

# %%
import cv2 as cv

# %%
x=load_img('sample.jpg',target_size=(100,100))
x
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1DB7AE89640>

# %%
x=img_to_array(x)/255.0
x=np.expand_dims(x,axis=0)

# %%
x1,y1,x2,y2=model.predict(x)[0][0]

# %%
image = cv.imread('sample.jpg')
image = imutils.resize(image, width=100)
(h, w) = image.shape[:2]
startX = int(x1* w)
startY = int(y1 * h)
endX = int(x2* w)
endY = int(y2 * h)
cv2.rectangle(image, (startX, startY), (endX, endY),(0, 255, 0), 2)
cv2.imshow("Output", image)
cv2.waitKey('q')

# %%
model.save('testing_image.h5')
